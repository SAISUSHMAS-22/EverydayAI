# %%
import cv2
import numpy as np
import os

def collage_images(image_paths, output_path, grid_size=(2, 2)):
    # Read images and resize them to fit the grid
    resized_images = []
    for image_path in image_paths:
        image = cv2.imread(image_path)
        resized_image = cv2.resize(image, (0, 0), fx=0.5, fy=0.5)  # Resize images to half of their original size
        resized_images.append(resized_image)

    # Calculate the dimensions of the grid
    num_rows, num_cols = grid_size

    # Calculate the size of the collage
    collage_height = resized_images[0].shape[0] * num_rows
    collage_width = resized_images[0].shape[1] * num_cols

    # Create a blank canvas for the collage
    collage = np.zeros((collage_height, collage_width, 3), dtype=np.uint8)

    # Paste images onto the collage
    idx = 0
    for i in range(num_rows):
        for j in range(num_cols):
            start_row = i * resized_images[idx].shape[0]
            end_row = (i + 1) * resized_images[idx].shape[0]
            start_col = j * resized_images[idx].shape[1]
            end_col = (j + 1) * resized_images[idx].shape[1]
            collage[start_row:end_row, start_col:end_col] = resized_images[idx]
            idx += 1
            if idx >= len(resized_images):
                break

    # Save the collage image
    cv2.imwrite(output_path, collage)

# Example usage:
# List of image paths
image_paths = ["path/to/image1.jpg", "path/to/image2.jpg", "path/to/image3.jpg", "path/to/image4.jpg"]

# Output path for saving the collage image
output_path = "collage.jpg"

# Create collage
collage_images(image_paths, output_path, grid_size=(2, 2))

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)

# %%
pip install rembg
# Out:
# Collecting rembg
#   Downloading rembg-2.0.56-py3-none-any.whl (32 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from rembg) (4.19.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rembg) (1.25.2)
# Collecting onnxruntime (from rembg)
#   Downloading onnxruntime-1.17.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from rembg) (4.9.0.80)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from rembg) (9.4.0)
# Requirement already satisfied: pooch in /usr/local/lib/python3.10/dist-packages (from rembg) (1.8.1)
# Collecting pymatting (from rembg)
#   Downloading PyMatting-1.1.12-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from rembg) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from rembg) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from rembg) (4.66.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->rembg) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->rembg) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->rembg) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->rembg) (0.18.0)
# Collecting coloredlogs (from onnxruntime->rembg)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg) (24.3.25)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg) (24.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg) (1.12)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch->rembg) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch->rembg) (2.31.0)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.10/dist-packages (from pymatting->rembg) (0.58.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg) (3.2.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg) (1.6.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba!=0.49.0->pymatting->rembg) (0.41.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg) (2024.2.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->rembg)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime->rembg) (1.3.0)
# Installing collected packages: humanfriendly, pymatting, coloredlogs, onnxruntime, rembg
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.17.1 pymatting-1.1.12 rembg-2.0.56

# %% [markdown]
# ***REMOVING BACKGROUND***

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
from rembg import remove
import os

input_folder = '/content/input images'
output_folder = '/content/output'

os.makedirs(output_folder, exist_ok=True)

input_files = os.listdir(input_folder)

for input_file in input_files:
    input_path = os.path.join(input_folder, input_file)
    output_path = os.path.join(output_folder, f"output_{input_file.split('.')[0]}.png")

    with open(input_path, 'rb') as i:
        with open(output_path, 'wb') as o:
            input_data = i.read()
            output_data = remove(input_data)
            o.write(output_data)

    print(f"Background removed successfully for {input_file}. Output saved to {output_path}")
# Out:
# Downloading data from 'https://github.com/danielgatis/rembg/releases/download/v0.0.0/u2net.onnx' to file '/root/.u2net/u2net.onnx'.
# 100%|███████████████████████████████████████| 176M/176M [00:00<00:00, 39.3GB/s]
# Background removed successfully for pant2.jpeg. Output saved to /content/output/output_pant2.png
# Background removed successfully for pant.jpeg. Output saved to /content/output/output_pant.png
# Background removed successfully for pant3.jpeg. Output saved to /content/output/output_pant3.png
# Background removed successfully for Tshirt.jpeg. Output saved to /content/output/output_Tshirt.png
# Background removed successfully for Tshirt5.jpeg. Output saved to /content/output/output_Tshirt5.png
# Background removed successfully for Tshirt4.jpeg. Output saved to /content/output/output_Tshirt4.png
# Background removed successfully for Tshirt3.jpeg. Output saved to /content/output/output_Tshirt3.png
# Background removed successfully for Tshirt2.jpeg. Output saved to /content/output/output_Tshirt2.png

# %%
# Importing Required Modules
# !pip install rembg
from rembg import remove
from PIL import Image

# Store path of the image in the variable input_path
input_path = "/content/tshirt2.jpeg"

# Store path of the output image in the variable output_path
output_path = "output.png"

# Processing the image
input = Image.open(input_path)

# Removing the background from the given Image
output = remove(input)

#Saving the image in the given path
output.save(output_path)
# Out:
# Requirement already satisfied: rembg in /usr/local/lib/python3.10/dist-packages (2.0.56)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from rembg) (4.19.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rembg) (1.25.2)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.10/dist-packages (from rembg) (1.17.1)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from rembg) (4.9.0.80)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from rembg) (9.4.0)
# Requirement already satisfied: pooch in /usr/local/lib/python3.10/dist-packages (from rembg) (1.8.1)
# Requirement already satisfied: pymatting in /usr/local/lib/python3.10/dist-packages (from rembg) (1.1.12)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from rembg) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from rembg) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from rembg) (4.66.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->rembg) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->rembg) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->rembg) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->rembg) (0.18.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg) (24.3.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg) (24.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg) (1.12)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch->rembg) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch->rembg) (2.31.0)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.10/dist-packages (from pymatting->rembg) (0.58.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg) (3.2.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg) (1.5.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba!=0.49.0->pymatting->rembg) (0.41.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg) (2024.2.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime->rembg) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime->rembg) (1.3.0)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-b6e00c959371> in <cell line: 16>()
#      14
#      15 # Removing the background from the given Image
# ---> 16 output = remove(input)
#      17
#      18 #Saving the image in the given path
#
# /usr/local/lib/python3.10/dist-packages/rembg/bg.py in remove(data, alpha_matting, alpha_matting_foreground_threshold, alpha_matting_background_threshold, alpha_matting_erode_size, session, only_mask, post_process_mask, bgcolor, *args, **kwargs)
#     253
#     254     # Fix image orientation
# --> 255     img = fix_image_orientation(img)
#     256
#     257     if session is None:
#
# /usr/local/lib/python3.10/dist-packages/rembg/bg.py in fix_image_orientation(img)
#     193         PILImage: The fixed image.
#     194     """
# --> 195     return ImageOps.exif_transpose(img)
#     196
#     197
#
# /usr/local/lib/python3.10/dist-packages/PIL/ImageOps.py in exif_transpose(image)
#     617                     )
#     618         return transposed_image
# --> 619     return image.copy()
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in copy(self)
#    1203         :returns: An :py:class:`~PIL.Image.Image` object.
#    1204         """
# -> 1205         self.load()
#    1206         return self._new(self.im.copy())
#    1207
#
# /usr/local/lib/python3.10/dist-packages/PIL/ImageFile.py in load(self)
#     264                                         f"({len(b)} bytes not processed)"
#     265                                     )
# --> 266                                     raise OSError(msg)
#     267
#     268                             b = b + s
#
# OSError: image file is truncated (15 bytes not processed)

# %% [markdown]
# ***COLLAGE***

# %%
import cv2
import numpy as np
import os

def resize_images(image_paths, target_size=(400, 400)):
    resized_images = []
    for image_path in image_paths:
        image = cv2.imread(image_path)
        resized_image = cv2.resize(image, target_size)
        resized_images.append(resized_image)
    return resized_images

def collage_images(image_paths, output_path, grid_size=(2, 2)):
    # Resize images to have the same dimensions
    resized_images = resize_images(image_paths)

    # Calculate the dimensions of the grid
    num_rows, num_cols = grid_size

    # Calculate the size of the collage
    collage_height = resized_images[0].shape[0] * num_rows
    collage_width = resized_images[0].shape[1] * num_cols

    # Create a blank canvas for the collage
    collage = np.zeros((collage_height, collage_width, 3), dtype=np.uint8)

    # Paste images onto the collage
    idx = 0
    for i in range(num_rows):
        for j in range(num_cols):
            start_row = i * resized_images[idx].shape[0]
            end_row = (i + 1) * resized_images[idx].shape[0]
            start_col = j * resized_images[idx].shape[1]
            end_col = (j + 1) * resized_images[idx].shape[1]
            collage[start_row:end_row, start_col:end_col] = resized_images[idx]
            idx += 1
            if idx >= len(resized_images):
                break

    # Save the collage image
    cv2.imwrite(output_path, collage)

# Example usage:
# List of image paths
image_paths = ["/content/output"]


# Output path for saving the collage image
output_path = "collage.jpg"

# Create collage
collage_images(image_paths, output_path, grid_size=(2, 2))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-15-b02712baeee5> in <cell line: 52>()
#      50
#      51 # Create collage
# ---> 52 collage_images(image_paths, output_path, grid_size=(2, 2))
#
# <ipython-input-15-b02712baeee5> in collage_images(image_paths, output_path, grid_size)
#      13 def collage_images(image_paths, output_path, grid_size=(2, 2)):
#      14     # Resize images to have the same dimensions
# ---> 15     resized_images = resize_images(image_paths)
#      16
#      17     # Calculate the dimensions of the grid
#
# <ipython-input-15-b02712baeee5> in resize_images(image_paths, target_size)
#       7     for image_path in image_paths:
#       8         image = cv2.imread(image_path)
# ----> 9         resized_image = cv2.resize(image, target_size)
#      10         resized_images.append(resized_image)
#      11     return resized_images
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/resize.cpp:4062: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %% [markdown]
# ***DIFFERENT QUILT PATTERNS***

# %%
import cv2
import numpy as np
import random

def crop_clothes_into_pieces(image_path, piece_size):
    # Read the image of the clothes
    clothes = cv2.imread(image_path)

    # Get dimensions of the clothes image
    height, width, _ = clothes.shape

    # Calculate the number of rows and columns for cropping
    num_rows = height // piece_size
    num_cols = width // piece_size

    # Initialize a list to store the cropped pieces
    cropped_pieces = []

    # Crop the clothes into pieces
    for i in range(num_rows):
        for j in range(num_cols):
            start_row = i * piece_size
            end_row = (i + 1) * piece_size
            start_col = j * piece_size
            end_col = (j + 1) * piece_size
            piece = clothes[start_row:end_row, start_col:end_col]
            cropped_pieces.append(piece)

    return cropped_pieces

def shuffle_pieces(cropped_pieces):
    # Shuffle the order of cropped pieces
    random.shuffle(cropped_pieces)

def create_quilt_pattern(cropped_pieces, num_rows, num_cols):
    # Initialize the quilt image
    quilt_height = cropped_pieces[0].shape[0] * num_rows
    quilt_width = cropped_pieces[0].shape[1] * num_cols
    quilt = np.zeros((quilt_height, quilt_width, 3), dtype=np.uint8)

    # Arrange the cropped pieces in a quilt pattern
    idx = 0
    for i in range(num_rows):
        for j in range(num_cols):
            start_row = i * cropped_pieces[0].shape[0]
            end_row = (i + 1) * cropped_pieces[0].shape[0]
            start_col = j * cropped_pieces[0].shape[1]
            end_col = (j + 1) * cropped_pieces[0].shape[1]
            quilt[start_row:end_row, start_col:end_col] = cropped_pieces[idx]
            idx += 1

    return quilt

def save_quilt(quilt, output_path):
    cv2.imwrite(output_path, quilt)

# Path to the image of the clothes
image_path ="collage.jpg"

# Size of each square piece for cropping
piece_size = 100

# Crop the clothes into pieces
cropped_pieces = crop_clothes_into_pieces(image_path, piece_size)

# Create three different quilt patterns
for pattern_num in range(3):
    # Shuffle the order of cropped pieces
    shuffle_pieces(cropped_pieces)

    # Number of rows and columns for the quilt layout
    num_rows = 8
    num_cols = 8

    # Create the quilt pattern
    quilt = create_quilt_pattern(cropped_pieces, num_rows, num_cols)

    # Output path for saving the quilt image
    output_path = f"quilt_pattern_{pattern_num + 1}.jpg"

    # Save the quilt image
    save_quilt(quilt, output_path)

# %%
import cv2
import numpy as np
import random
import os

def resize_images(image_paths, target_size=(400, 400)):
    resized_images = []
    for image_path in image_paths:
        image = cv2.imread(image_path)
        resized_image = cv2.resize(image, target_size)
        resized_images.append(resized_image)
    return resized_images

def collage_images(image_paths, output_path, grid_size=(2, 2)):
    # Resize images to have the same dimensions
    resized_images = resize_images(image_paths)

    # Calculate the dimensions of the grid
    num_rows, num_cols = grid_size

    # Calculate the size of the collage
    collage_height = resized_images[0].shape[0] * num_rows
    collage_width = resized_images[0].shape[1] * num_cols

    # Create a blank canvas for the collage
    collage = np.zeros((collage_height, collage_width, 3), dtype=np.uint8)

    # Paste images onto the collage
    idx = 0
    for i in range(num_rows):
        for j in range(num_cols):
            start_row = i * resized_images[idx].shape[0]
            end_row = (i + 1) * resized_images[idx].shape[0]
            start_col = j * resized_images[idx].shape[1]
            end_col = (j + 1) * resized_images[idx].shape[1]
            collage[start_row:end_row, start_col:end_col] = resized_images[idx]
            idx += 1
            if idx >= len(resized_images):
                break

    # Save the collage image
    cv2.imwrite(output_path, collage)

def crop_clothes_into_pieces(image_path, piece_size):
    # Read the image of the clothes
    clothes = cv2.imread(image_path)

    # Get dimensions of the clothes image
    height, width, _ = clothes.shape

    # Calculate the number of rows and columns for cropping
    num_rows = height // piece_size
    num_cols = width // piece_size

    # Initialize a list to store the cropped pieces
    cropped_pieces = []

    # Crop the clothes into pieces
    for i in range(num_rows):
        for j in range(num_cols):
            start_row = i * piece_size
            end_row = (i + 1) * piece_size
            start_col = j * piece_size
            end_col = (j + 1) * piece_size
            piece = clothes[start_row:end_row, start_col:end_col]
            cropped_pieces.append(piece)

    return cropped_pieces

def shuffle_pieces(cropped_pieces):
    # Shuffle the order of cropped pieces
    random.shuffle(cropped_pieces)

def create_quilt_pattern(cropped_pieces, num_rows, num_cols):
    # Initialize the quilt image
    quilt_height = cropped_pieces[0].shape[0] * num_rows
    quilt_width = cropped_pieces[0].shape[1] * num_cols
    quilt = np.zeros((quilt_height, quilt_width, 3), dtype=np.uint8)

    # Arrange the cropped pieces in a quilt pattern
    idx = 0
    for i in range(num_rows):
        for j in range(num_cols):
            start_row = i * cropped_pieces[0].shape[0]
            end_row = (i + 1) * cropped_pieces[0].shape[0]
            start_col = j * cropped_pieces[0].shape[1]
            end_col = (j + 1) * cropped_pieces[0].shape[1]
            quilt[start_row:end_row, start_col:end_col] = cropped_pieces[idx]
            idx += 1

    return quilt

def save_quilt(quilt, output_path):
    cv2.imwrite(output_path, quilt)

# Example usage:
# List of image paths
image_paths = ["Tshirt.jpeg", "Tshirt2.jpeg", "Tshirt3.jpeg", "Tshirt4.jpeg", "Tshirt5.jpeg", "pant.jpeg", "pant2.jpeg", "pant3.jpeg"]

# Output path for saving the collage image
collage_output_path = "collage.jpg"

# Create collage
collage_images(image_paths, collage_output_path, grid_size=(2, 2))

# Path to the collage image
image_path = "collage.jpg"

# Size of each square piece for cropping
piece_size = 100

# Crop the clothes into pieces
cropped_pieces = crop_clothes_into_pieces(image_path, piece_size)

# Create three different quilt patterns
for pattern_num in range(3):
    # Shuffle the order of cropped pieces
    shuffle_pieces(cropped_pieces)

    # Number of rows and columns for the quilt layout
    num_rows = 8
    num_cols = 8

    # Create the quilt pattern
    quilt = create_quilt_pattern(cropped_pieces, num_rows, num_cols)

    # Output path for saving the quilt image
    quilt_output_path = f"quilt_no{pattern_num + 1}.jpg"

    # Save the quilt image
    save_quilt(quilt, quilt_output_path)

# %% [markdown]
# **This is the final code for three quilt generation**

# %%
import cv2
import numpy as np
import random
import os

def resize_images(image_paths, target_size=(400, 400)):
    resized_images = []
    for image_path in image_paths:
        image = cv2.imread(image_path)
        resized_image = cv2.resize(image, target_size)
        resized_images.append(resized_image)
    return resized_images

def collage_images(image_paths, output_path, grid_size=(2, 2)):
    # Resize images to have the same dimensions
    resized_images = resize_images(image_paths)

    # Calculate the dimensions of the grid
    num_rows, num_cols = grid_size

    # Calculate the size of the collage
    collage_height = resized_images[0].shape[0] * num_rows
    collage_width = resized_images[0].shape[1] * num_cols

    # Create a blank canvas for the collage
    collage = np.zeros((collage_height, collage_width, 3), dtype=np.uint8)

    # Paste images onto the collage
    idx = 0
    for i in range(num_rows):
        for j in range(num_cols):
            start_row = i * resized_images[idx].shape[0]
            end_row = (i + 1) * resized_images[idx].shape[0]
            start_col = j * resized_images[idx].shape[1]
            end_col = (j + 1) * resized_images[idx].shape[1]
            collage[start_row:end_row, start_col:end_col] = resized_images[idx]
            idx += 1
            if idx >= len(resized_images):
                break

    # Save the collage image
    cv2.imwrite(output_path, collage)

def crop_clothes_into_pieces(image_path, piece_size):
    # Read the image of the clothes
    clothes = cv2.imread(image_path)

    # Get dimensions of the clothes image
    height, width, _ = clothes.shape

    # Calculate the number of rows and columns for cropping
    num_rows = height // piece_size
    num_cols = width // piece_size

    # Initialize a list to store the cropped pieces
    cropped_pieces = []

    # Crop the clothes into pieces
    for i in range(num_rows):
        for j in range(num_cols):
            start_row = i * piece_size
            end_row = (i + 1) * piece_size
            start_col = j * piece_size
            end_col = (j + 1) * piece_size
            piece = clothes[start_row:end_row, start_col:end_col]
            cropped_pieces.append(piece)

    return cropped_pieces

def shuffle_pieces(cropped_pieces):
    # Shuffle the order of cropped pieces
    random.shuffle(cropped_pieces)

def create_quilt_pattern(cropped_pieces, num_rows, num_cols):
    # Initialize the quilt image
    quilt_height = cropped_pieces[0].shape[0] * num_rows
    quilt_width = cropped_pieces[0].shape[1] * num_cols
    quilt = np.zeros((quilt_height, quilt_width, 3), dtype=np.uint8)

    # Arrange the cropped pieces in a quilt pattern
    idx = 0
    for i in range(num_rows):
        for j in range(num_cols):
            start_row = i * cropped_pieces[0].shape[0]
            end_row = (i + 1) * cropped_pieces[0].shape[0]
            start_col = j * cropped_pieces[0].shape[1]
            end_col = (j + 1) * cropped_pieces[0].shape[1]
            quilt[start_row:end_row, start_col:end_col] = cropped_pieces[idx]
            idx += 1

    return quilt

def save_quilt(quilt, output_path):
    cv2.imwrite(output_path, quilt)

# Function to get all image paths from a folder
def get_image_paths_from_folder(folder_path):
    image_paths = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith(('.jpg', '.jpeg', '.png', '.bmp')):
            image_paths.append(os.path.join(folder_path, file_name))
    return image_paths

# Input folder path containing images
input_folder ="/content/input images"

# Get all image paths from the input folder
image_paths = get_image_paths_from_folder(input_folder)

# Output path for saving the collage image
collage_output_path = "collage.jpg"

# Create collage
collage_images(image_paths, collage_output_path, grid_size=(2, 2))

# Path to the collage image
image_path = "collage.jpg"

# Size of each square piece for cropping
piece_size = 100

# Crop the clothes into pieces
cropped_pieces = crop_clothes_into_pieces(image_path, piece_size)

# Create three different quilt patterns
for pattern_num in range(3):
    # Shuffle the order of cropped pieces
    shuffle_pieces(cropped_pieces)

    # Number of rows and columns for the quilt layout
    num_rows = 8
    num_cols = 8

    # Create the quilt pattern
    quilt = create_quilt_pattern(cropped_pieces, num_rows, num_cols)

    # Output path for saving the quilt image
    quilt_output_path = f"quilt_no{pattern_num + 1}.jpg"

    # Save the quilt image
    save_quilt(quilt, quilt_output_path)
